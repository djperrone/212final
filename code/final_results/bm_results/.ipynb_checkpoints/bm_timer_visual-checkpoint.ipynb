# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib 
from matplotlib import pyplot as plt

# %%
data_url = "bm_timer_word1.csv"

# %%
bm_df1 = pd.read_csv(data_url)

# %%
bm_df1['pat_len'] = [1 for i in bm_df1.index]

# %%
bm_df10 = pd.read_csv("bm_timer_word10.csv")

# %%
bm_df10['pat_len'] = [10 for i in bm_df10.index]

# %%
bm_df50 = pd.read_csv("bm_timer_phrase50.csv")

# %%
bm_df50['pat_len'] = [50 for i in bm_df50.index]

# %%
bm_df100 = pd.read_csv("bm_timer_phrase100.csv")

# %%
bm_df100['pat_len'] = [100 for i in bm_df100.index]

# %%
bm_df1000 = pd.read_csv("bm_timer_char1000.csv")

# %%
bm_df1000['pat_len'] = [1000 for i in bm_df1000.index]

# %%
df_list = [bm_df1,bm_df10,bm_df50,bm_df100,bm_df1000]

# %%
text_len = []
pat_len = []
time = []

# %%
rows = []
cols = []
for df in df_list:
    for i in range(0,len(df.index),5):  
        text_len.append(df['str_len'].values[i])
        time.append(df['duration'].values[i:i+5].mean())
        pat_len.append(df['pat_len'].values[i])

# %%
bm_avg_df = pd.DataFrame(columns =['text_len','pat_len','time'])

# %%
bm_avg_df
# Out:
# Empty DataFrame
# Columns: [text_len, pat_len, time]
# Index: []

# %%
bm_avg_df['text_len']=[i for i in text_len]
bm_avg_df['pat_len']=[i for i in pat_len]
bm_avg_df['time']=[i for i in time]

# %%
bm_avg_df
# Out:
#     text_len  pat_len      time
# 0         13        1   0.00154
# 1        101        1   0.00110
# 2       1045        1   0.00244
# 3      48733        1   0.08502
# 4      10183        1   0.02670
# 5     185919        1   0.42720
# 6     559618        1   0.97290
# 7    1010777        1   1.85382
# 8    2665788        1   4.62520
# 9    4808754        1   7.95298
# 10  24652312        1  40.71850
# 11  48087540        1  81.59752
# 12        13       10   0.00306
# 13       101       10   0.00250
# 14      1045       10   0.00484
# 15     48733       10   0.09992
# 16     10183       10   0.02488
# 17    185919       10   0.36856
# 18    559618       10   0.93116
# 19   1010777       10   1.75882
# 20   2665788       10   4.31668
# 21   4808754       10   7.61988
# 22  24652312       10  38.90780
# 23  48087540       10  77.24132
# 24        13       50   0.00936
# 25       101       50   0.00878
# 26      1045       50   0.01270
# 27     48733       50   0.05768
# 28     10183       50   0.01828
# 29    185919       50   0.17516
# 30    559618       50   0.54058
# 31   1010777       50   0.95484
# 32   2665788       50   2.50428
# 33   4808754       50   4.35600
# 34  24652312       50  22.19216
# 35  48087540       50  43.14558
# 36        13      100   0.02488
# 37       101      100   0.02804
# 38      1045      100   0.02692
# 39     48733      100   0.06734
# 40     10183      100   0.03124
# 41    185919      100   0.14912
# 42    559618      100   0.36078
# 43   1010777      100   0.67178
# 44   2665788      100   1.79450
# 45   4808754      100   2.91926
# 46  24652312      100  15.03890
# 47  48087540      100  29.64014
# 48        13     1000   1.52222
# 49       101     1000   1.35576
# 50      1045     1000   1.46532
# 51     48733     1000   1.48826
# 52     10183     1000   1.35594
# 53    185919     1000   1.45944
# 54    559618     1000   1.60862
# 55   1010777     1000   1.68792
# 56   2665788     1000   2.16892
# 57   4808754     1000   2.89456
# 58  24652312     1000   9.59382
# 59  48087540     1000  17.95776

# %%
bm_matrix = bm_avg_df.pivot('text_len','pat_len','time')

# %%
bm_avg_df['time'].min()
# Out:
# 0.0011

# %%
heatmap = sns.heatmap(data=bm_matrix,cmap='BuPu',vmin=bm_avg_df['time'].min(),vmax=bm_avg_df['time'].max()).invert_yaxis()
