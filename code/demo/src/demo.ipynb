# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib 
from matplotlib import pyplot as plt

# %%
data_url = "bm_timer_ex1.csv"

# %%
bm_df = pd.read_csv(data_url)

# %%
#bm_df['pat_len'] = [8 for i in bm_df.index]

# %%
text_len = []
pat_len = []
time = []

# %%
rows = []
cols = []

for i in range(0,len(bm_df.index),5):  
    text_len.append(bm_df['str_len'].values[i])
    time.append(bm_df['duration'].values[i:i+5].mean())
    pat_len.append(bm_df['pat_len'].values[i])

# %%
bm_results_df = pd.DataFrame(columns =['text_len','pat_len','time'])

# %%
bm_results_df['text_len']=[i for i in text_len]
bm_results_df['pat_len']=[i for i in pat_len]
bm_results_df['time']=[i for i in time]

# %%
bm_results_df
# Out:
#     text_len  pat_len      time
# 0         13       10   0.00362
# 1        101       10   0.00388
# 2       1045       10   0.00438
# 3      48733       10   0.09502
# 4      10183       10   0.02242
# 5     185919       10   0.32682
# 6     559618       10   1.12476
# 7    1010777       10   1.80270
# 8    2665788       10   6.04840
# 9    4808754       10   9.82350
# 10  24652312       10  46.84496
# 11  48087540       10  98.28788

# %%
rk_df = pd.read_csv("rk_timer_ex1-293.csv")

# %%
#rk_df['pat_len'] = [8 for i in bm_df.index]

# %%
text_len = []
pat_len = []
time = []
for i in range(0,len(rk_df.index),5):  
    text_len.append(rk_df['str_len'].values[i])
    time.append(rk_df['duration'].values[i:i+5].mean())
    pat_len.append(rk_df['pat_len'].values[i])

# %%
rk_results_df = pd.DataFrame(columns =['text_len','pat_len','time'])

# %%
rk_results_df['text_len']=[i for i in text_len]
rk_results_df['pat_len']=[i for i in pat_len]
rk_results_df['time']=[i for i in time]

# %%
rk_results_df
# Out:
#     text_len  pat_len       time
# 0         13       29    0.00098
# 1        101       29    0.00120
# 2       1045       29    0.00592
# 3      48733       29    0.21930
# 4      10183       29    0.04482
# 5     185919       29    0.90300
# 6     559618       29    2.83108
# 7    1010777       29    4.62318
# 8    2665788       29   13.04616
# 9    4808754       29   23.89688
# 10  24652312       29  126.14660
# 11  48087540       29  239.19240

# %%
bm_results_df
# Out:
#     text_len  pat_len      time
# 0         13       10   0.00362
# 1        101       10   0.00388
# 2       1045       10   0.00438
# 3      48733       10   0.09502
# 4      10183       10   0.02242
# 5     185919       10   0.32682
# 6     559618       10   1.12476
# 7    1010777       10   1.80270
# 8    2665788       10   6.04840
# 9    4808754       10   9.82350
# 10  24652312       10  46.84496
# 11  48087540       10  98.28788

# %%
df = pd.concat([bm_results_df,rk_results_df])

# %%
df
# Out:
#     text_len  pat_len       time
# 0         13       10    0.00362
# 1        101       10    0.00388
# 2       1045       10    0.00438
# 3      48733       10    0.09502
# 4      10183       10    0.02242
# 5     185919       10    0.32682
# 6     559618       10    1.12476
# 7    1010777       10    1.80270
# 8    2665788       10    6.04840
# 9    4808754       10    9.82350
# 10  24652312       10   46.84496
# 11  48087540       10   98.28788
# 0         13       29    0.00098
# 1        101       29    0.00120
# 2       1045       29    0.00592
# 3      48733       29    0.21930
# 4      10183       29    0.04482
# 5     185919       29    0.90300
# 6     559618       29    2.83108
# 7    1010777       29    4.62318
# 8    2665788       29   13.04616
# 9    4808754       29   23.89688
# 10  24652312       29  126.14660
# 11  48087540       29  239.19240

# %%
#df['algorithm'] = ['BoyerMoore','BoyerMoore','BoyerMoore','BoyerMoore','BoyerMoore','RabinKarp','RabinKarp','RabinKarp','RabinKarp','RabinKarp',]

# %%
df
# Out:
#     text_len  pat_len       time
# 0         13       10    0.00362
# 1        101       10    0.00388
# 2       1045       10    0.00438
# 3      48733       10    0.09502
# 4      10183       10    0.02242
# 5     185919       10    0.32682
# 6     559618       10    1.12476
# 7    1010777       10    1.80270
# 8    2665788       10    6.04840
# 9    4808754       10    9.82350
# 10  24652312       10   46.84496
# 11  48087540       10   98.28788
# 0         13       29    0.00098
# 1        101       29    0.00120
# 2       1045       29    0.00592
# 3      48733       29    0.21930
# 4      10183       29    0.04482
# 5     185919       29    0.90300
# 6     559618       29    2.83108
# 7    1010777       29    4.62318
# 8    2665788       29   13.04616
# 9    4808754       29   23.89688
# 10  24652312       29  126.14660
# 11  48087540       29  239.19240

# %%
bm_matrix = bm_results_df.pivot('text_len','pat_len','time')

# %%
lineplt = sns.lineplot(x=bm_results_df['text_len'],y=bm_results_df['time'],label = 'Boyer-Moore')
lineplt = sns.lineplot(x=rk_results_df['text_len'],y=rk_results_df['time'],label = 'Rabin-Karp')
